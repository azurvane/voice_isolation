# %%
import numpy as np

# %%
mixture = np.array([-2.0, 1.5, 0.8, -1.2])

# %%
mixture = 2*(mixture-np.min(mixture))/(np.max(mixture)-np.min(mixture)) - 1
print(mixture)
# Out:
# [-1.          1.          0.6        -0.54285714]

# %%
mixture = mixture * (0.9 / np.max(np.abs(mixture)))
print(mixture)
# Out:
# [-0.9         0.9         0.54       -0.48857143]
